# %% [markdown]
# # 实战1~定义一个圆的类计算面积和周长

# %% [markdown]
# ## 题目：定义一个圆的类计算面积和周长

# %% [markdown]
# 需求：定义一个圆类`Circle`，提供一个属性`r`(半径)，提供两个方法：计算圆的面积`get_area(self)`和计算圆的周长`get_perimeter(self)`，通过两个方法计算圆的周长和面积并且对计算结果进行输出，最后从键盘录入半径，创建圆类的对象，并调用计算面积和周长的方法输出面积和周长。
#
# ---

# %%
class Circle:

	def __init__(self,r):
		self.r=r


	#计算圆的面积：面积=πr平方
	def get_area(self):

		return 3.14*(self.r*self.r) 
 


    # 计算圆的周长：2πr
	def get_perimeter(self):
		return 2*3.14*self.r


if __name__ == '__main__':

    # eval函数：将字符串转换为相应的数据类型
	r=eval(input("请输入圆的半径："))

	# 创建对象
	c=Circle(r)

	area=c.get_area()
	perimeter=c.get_perimeter()

	print(f"圆的面积为：",area)
	print(f"圆的周长为：",perimeter)
# Out:
# 请输入圆的半径： 4.6
# 圆的面积为： 66.44239999999999
# 圆的周长为： 28.887999999999998

# %% [markdown]
# ---
# 本节涉及到得知识点：
#
# eval函数详解：https://blog.csdn.net/yueguang8/article/details/136518615
