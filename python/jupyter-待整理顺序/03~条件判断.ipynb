# %% [markdown]
# # 条件判断

# %% [markdown]
# ## 单向判断if

# %% [markdown]
# 举例：如果一个人的成绩大于或等于60分，他就及格了。

# %%
score = 60

if score >= 60:
    print('你及格了！')
# Out:
# 你及格了！

# %% [markdown]
# ## 双向判断：if…else…

# %% [markdown]
# 举例：成绩大于或等于60分，显示及格；小于60分显示不及格。

# %%
score = 40

if score >= 60:
    print('你及格了！')
else:
    print('你不及格')
# Out:
# 你不及格

# %% [markdown]
# ## 多向判断：if…elif…else…

# %%
score = 80

if 80 <= score < 100:
    print('你是学霸')
elif 0 <= score < 60:
    print('你不及格')
else:
    print('你及格了！')
# Out:
# 你是学霸

# %% [markdown]
# ## if的嵌套

# %%
score = 55

if score >= 60:
    print('你及格了')
    if score >= 80:
        print('你是学霸')
    else:
        print('你成绩一般')
else:
    print('你不及格')
# Out:
# 你不及格

# %%
score = 25

if score >= 60:
    print('你及格了')
    if score >= 80:
        print('你是学霸')
    else:
        print('你成绩一般')
else:
    print('你不及格')
    if score < 30:
        print('你就是个学渣，没救了')
    else:
        print('不算太糟糕，还能拯救')
# Out:
# 你不及格
# 你就是个学渣，没救了
