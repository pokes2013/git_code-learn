# %% [markdown]
# ## 字符串连续过滤

# %%
# 定义一个包含多个要检查字符串的列表
filter_strings = ["download_zh.png", "actjpgs"]
# 检查item是否不包含列表中的任何一个字符串
if not any(s in item for s in filter_strings):
    # 如果item不包含列表中的任何一个字符串，‌则执行这里的代码
    print("过滤条件满足")
