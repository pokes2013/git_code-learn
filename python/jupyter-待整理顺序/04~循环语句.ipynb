# %% [markdown]
# ## for循环

# %% [markdown]
# 打印出1-9每个数字，（1,10）包前不包后1-9，不包含10

# %%
for i in range(1,10):
    print(i)

# %%
for ch in 'python':
    print(ch)

# %% [markdown]
# ## while循环

# %% [markdown]
# 实例：打印1-5的数字？

# %%
a=1
while a<=5:
    print(a)
    a=a+1

# %% [markdown]
# 打印出1-20内能被3整除的数字

# %%
#方法1
a = 1
while a <=20 :
    if a%3==0:
        print(a)
    a+=1
# Out:
# 3
# 6
# 9
# 12
# 15
# 18

# %%
#方法2
a = 3
while a < 20:
    print(a)
    a=a+3
# Out:
# 3
# 6
# 9
# 12
# 15
# 18

# %%
#打印出1-30内，既能被3整除，又能被5整除的数

a = 1
while a <=30 :
    if a%3==0 and a%5==0:
        print(a)
    a+=1

#注意：这里a+=1是和if对齐的
# Out:
# 15
# 30
